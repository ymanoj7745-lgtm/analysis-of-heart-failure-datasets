# %%
import pandas as pd

# %%
df = pd.read_csv("Heart_Disease_Prediction.csv")

# %%
df.isnull()
#there is no null data in the csv file
# Out:
#        Age    Sex  Chest pain type     BP  Cholesterol  FBS over 120  \
# 0    False  False            False  False        False         False
# 1    False  False            False  False        False         False
# 2    False  False            False  False        False         False
# 3    False  False            False  False        False         False
# 4    False  False            False  False        False         False
# ..     ...    ...              ...    ...          ...           ...
# 265  False  False            False  False        False         False
# 266  False  False            False  False        False         False
# 267  False  False            False  False        False         False
# 268  False  False            False  False        False         False
# 269  False  False            False  False        False         False
#
#      EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# ...

# %%
df.isnull().sum()
#there are zero missing values as we can see
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 265    False
# 266    False
# 267    False
# 268    False
# 269    False
# Length: 270, dtype: bool

# %%
df.dtypes
# Out:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
#this data is cleaned so we can reshape it

# %%
df.sort_values("Age")
df.sort_values(["Age", "Cholesterol"])
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 214   29    1                2  130          204             0            2
# 174   34    1                1  118          182             0            2
# 138   34    0                2  118          210             0            0
# 224   35    0                4  138          183             0            0
# 81    35    1                4  120          198             0            0
# ..   ...  ...              ...  ...          ...           ...          ...
# 29    71    0                3  110          265             1            2
# 255   71    0                2  160          302             0            0
# 4     74    0                2  120          269             0            2
# 73    76    0                3  140          197             0            1
# 199   77    1                4  125          304             0            2
#
# ...
