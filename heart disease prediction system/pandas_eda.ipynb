# %%
import pandas as pd

# %%
df = pd.read_csv("Heart_Disease_Prediction.csv")

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=270, step=1)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
df.tail()
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 265                        0         7       Absence
# 266                        0         7       Absence
# ...

# %%
df[["Chest pain type", "Heart Disease"]]
# Out:
#      Chest pain type Heart Disease
# 0                  4      Presence
# 1                  3       Absence
# 2                  2      Presence
# 3                  4       Absence
# 4                  2       Absence
# ..               ...           ...
# 265                3       Absence
# 266                2       Absence
# 267                2       Absence
# 268                4       Absence
# 269                4      Presence
#
# [270 rows x 2 columns]

# %%
df.loc[0]
# Out:
# Age                              70
# Sex                               1
# Chest pain type                   4
# BP                              130
# Cholesterol                     322
# FBS over 120                      0
# EKG results                       2
# Max HR                          109
# Exercise angina                   0
# ST depression                   2.4
# Slope of ST                       2
# Number of vessels fluro           3
# Thallium                          3
# Heart Disease              Presence
# Name: 0, dtype: object

# %%
df.loc[50]
# Out:
# Age                              42
# Sex                               1
# Chest pain type                   4
# BP                              136
# Cholesterol                     315
# FBS over 120                      0
# EKG results                       0
# Max HR                          125
# Exercise angina                   1
# ST depression                   1.8
# Slope of ST                       2
# Number of vessels fluro           0
# Thallium                          6
# Heart Disease              Presence
# Name: 50, dtype: object

# %%
df.iloc[0]
# Out:
# Age                              70
# Sex                               1
# Chest pain type                   4
# BP                              130
# Cholesterol                     322
# FBS over 120                      0
# EKG results                       2
# Max HR                          109
# Exercise angina                   0
# ST depression                   2.4
# Slope of ST                       2
# Number of vessels fluro           3
# Thallium                          3
# Heart Disease              Presence
# Name: 0, dtype: object

# %%
df.iloc[50]
# Out:
# Age                              42
# Sex                               1
# Chest pain type                   4
# BP                              136
# Cholesterol                     315
# FBS over 120                      0
# EKG results                       0
# Max HR                          125
# Exercise angina                   1
# ST depression                   1.8
# Slope of ST                       2
# Number of vessels fluro           0
# Thallium                          6
# Heart Disease              Presence
# Name: 50, dtype: object

# %%
#people who are age is greater than 30
df[df["Age"] > 30]
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
#patients who are age is greate than 30 and heatfailure risk condtion 
df[(df["Age"]>30) & 
   (df["BP"]>130) & 
   (["Heart Disease"] == "Presence")]
filtered_df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 8     60    1                4  140          293             0            2
# 9     63    0                4  150          407             0            2
# 13    61    1                1  134          234             0            0
# 16    46    1                4  140          311             0            0
# 17    53    1                4  140          203             1            2
# 33    59    1                4  170          326             0            2
# 34    50    1                4  144          200             0            2
# 36    61    1                4  140          207             0            2
# 37    59    1                1  160          273             0            2
# 40    40    1                4  152          223             0            0
# 48    66    1                2  160          246             0            0
# ...

# %%
#same problem with query method
df.query("Age > 40 and `Exercise angina` == 0")
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 5     65    1                4  120          177             0            0
# 8     60    1                4  140          293             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 264   48    1                2  110          229             0            0
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
#
# ...

# %%
col = "Heart Disease"
df.query(f"`{col}` == 'presence'")
filtered_df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 8     60    1                4  140          293             0            2
# 9     63    0                4  150          407             0            2
# 13    61    1                1  134          234             0            0
# 16    46    1                4  140          311             0            0
# 17    53    1                4  140          203             1            2
# 33    59    1                4  170          326             0            2
# 34    50    1                4  144          200             0            2
# 36    61    1                4  140          207             0            2
# 37    59    1                1  160          273             0            2
# 40    40    1                4  152          223             0            0
# 48    66    1                2  160          246             0            0
# ...

# %%
df.query("30 <Age <=40")
filtered_df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 8     60    1                4  140          293             0            2
# 9     63    0                4  150          407             0            2
# 13    61    1                1  134          234             0            0
# 16    46    1                4  140          311             0            0
# 17    53    1                4  140          203             1            2
# 33    59    1                4  170          326             0            2
# 34    50    1                4  144          200             0            2
# 36    61    1                4  140          207             0            2
# 37    59    1                1  160          273             0            2
# 40    40    1                4  152          223             0            0
# 48    66    1                2  160          246             0            0
# ...

# %%
df[df["Age"] > 75]
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 73    76    0                3  140          197             0            1
# 199   77    1                4  125          304             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 73      116                0            1.1            2
# 199     162                1            0.0            1
#
#      Number of vessels fluro  Thallium Heart Disease
# 73                         0         3       Absence
# 199                        3         3      Presence

# %%
df[df["Age"] >60]
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# 5     65    1                4  120          177             0            0
# ..   ...  ...              ...  ...          ...           ...          ...
# 247   65    0                3  155          269             0            0
# 255   71    0                2  160          302             0            0
# 256   61    1                3  150          243             1            0
# 258   64    1                3  140          335             0            0
# 269   67    1                4  160          286             0            2
#
# ...
